# %%
import pandas as pd
import etl_shared
df_short_names = etl_shared.start(etl_shared.etl_Hasmig)

# %%
df_short_names.head()
# Out:
#   State  Zip  AGI   Returns    Single     Joint         AGI  Total_Income  \
# 0    AL    0    1  720280.0  466930.0   75840.0   9323038.0     9449210.0
# 1    AL    0    2  524160.0  264900.0  109720.0  18959208.0    19094415.0
# 2    AL    0    3  291860.0  120090.0  116380.0  17933235.0    18056325.0
# 3    AL    0    4  184320.0   48650.0  115740.0  15990196.0    16092775.0
# 4    AL    0    5  287720.0   38750.0  234070.0  39500365.0    39796286.0
#
#    Cap_Gain_Returns  Cap_Gain_Amt  ...  Med_Dental_Returns  Med_Dental_Amt  \
# 0           37020.0       64524.0  ...              4390.0         67120.0
# 1           38080.0      128686.0  ...             10660.0        145487.0
# 2           39930.0      210305.0  ...              8720.0        119946.0
# 3           34910.0      265069.0  ...              5220.0         80579.0
# 4           89550.0     1420250.0  ...              7840.0        136108.0
#
# ...
